# %% [markdown]
# <a href="https://colab.research.google.com/github/samerhanze/CVIP2025/blob/main/02_SIR_Diagnostics_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/arrjon/BayesFlowTutorial/blob/main/02_SIR_Diagnostics_Exercise.ipynb)
#
# To use the GPU in Google Colab, click **Runtime ▸ Change runtime type ▸ Hardware accelerator ▸ T4 GPU**. We automatically install jax with GPU support. However, this notebook will run fine on CPU as well but will be slower.

# %% [markdown]
# # BayesFlow 2 — SIR Epidemic Models & Diagnostics
#
# **Difficulty:** 🟡 Intermediate  ·
#
# > 🎯 **What you will learn**
# > - Build an amortized posterior estimator for a mechanistic **time-series** model (an SIR ODE + noisy reporting).
# > - Use a **recurrent summary network** (GRU) to compress a case-count time series.
# > - Run and *interpret* the full BayesFlow diagnostic suite: SBC histograms/ECDF, recovery, posterior contraction, and spot **non-identifiability**.
# > - Confront the trained network with **real COVID-19 data** and judge model adequacy with a **posterior predictive check**.
#
# ---
#
# > ✏️ **How this notebook works.** Run each cell and look for **`TODO`** markers. Each one asks you to fill in a small piece of code.
#
# Created by [Jonas Arruda](https://github.com/arrjon) based on tutorials of [BayesFlow](https://bayesflow.org) (August 2026).

# %%
# ▶️  RUN THIS FIRST.  Installs this tutorial project and all its dependencies
#     (BayesFlow, JAX, Pyro, ...) from GitHub, as declared in pyproject.toml (~1-2 min).
import sys, subprocess

print("Installing the tutorial and its dependencies — this takes ~1-2 min ...")
_res = subprocess.run(
    [sys.executable, "-m", "pip", "install", "-q",
     "git+https://github.com/arrjon/BayesFlowTutorial.git"],
    capture_output=True, text=True,
)
if _res.returncode != 0:
    print(_res.stdout); print(_res.stderr)
    raise SystemExit("Install failed — see the pip output above.")

# NOTE: pip may internally warn that google-colab pins pandas==2.2.2 while BayesFlow
# needs pandas>=2.3.3. That warning is harmless and unavoidable (the tutorial doesn't use
# google-colab's pandas features).
print("✅ Setup complete.")
print("Do not run this cell again after the notebook restart.")
get_ipython().kernel.do_shutdown(restart=True)
# Out:
# Installing the tutorial and its dependencies — this takes ~1-2 min ...
# ✅ Setup complete.
# Do not run this cell again after the notebook restart.
# {'status': 'ok', 'restart': True}

# %%
import os
# BayesFlow runs on JAX, PyTorch or TensorFlow. We pick JAX here.
os.environ["KERAS_BACKEND"] = "jax"
import bayesflow as bf
# Out:
# INFO:bayesflow:Using backend 'jax'

# %% [markdown]
# > 📚 **Where to read more**
# > - BayesFlow website & docs: <https://bayesflow.org>
# > - Example gallery: <https://bayesflow.org/main/examples.html>
# > - BayesFlow guide: https://bayesflow.org/v2.0.12/user_guide/diagnostics.html

# %% [markdown]
# ## The SIR model
#
# We infer parameters of a stochastic epidemiological model. Individuals are **S**usceptible, **I**nfected or **R**ecovered, with transmission rate $\lambda$ and recovery rate $\mu$:
#
# $$\frac{dS}{dt} = -\lambda \frac{S I}{N},\quad \frac{dI}{dt} = \lambda \frac{S I}{N} - \mu I,\quad \frac{dR}{dt} = \mu I.$$
#
# We observe **daily reported new cases** for $T=14$ days. Reporting is imperfect: cases appear with a delay $D$ (an integer number of days) and are noisy, modelled with a **Negative-Binomial** observation model with dispersion $\psi$. The initial number of infected $I_0$ is also unknown. So we infer five parameters: $(\lambda, \mu, D, I_0, \psi)$.
#
# Background reading:
# - OutbreakFlow (Radev et al., 2021): <https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1009472>

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras

RNG = np.random.default_rng(2026)

# %% [markdown]
# ## 1. Prior & simulator
#
# We will place the following prior distributions over the five model parameters, summarized in the table below:
#
# $$
# \begin{aligned}
# & \text {Table 1. Description of model parameters and corresponding prior distributions}\\
# &\begin{array}{lcl}
# \hline \hline \text { Description} & \text { Symbol } & \text { Prior Distribution } \\
# \hline \hline \text{Initial transmission rate} & \text{$\lambda$} & \text{$\textrm{LogNormal}(\log(0.4), 0.5)$} \\
# \text{Recovery rate of infected individuals} & \text{$\mu$} & \text{$\textrm{LogNormal}(\log(1/8), 0.2)$} \\
# \text{Reporting delay (lag)} & \text{$D$} & \text{$\textrm{LogNormal}(\log(8), 0.2)$} \\
# \text{Number of initially infected individuals} & \text{$I_0$} & \text{$\textrm{Gamma}(2, 20)$} \\
# \text{Dispersion of the negative binomial distribution} & \text{$\psi$} & \text{$\textrm{Exponential}(5)$} \\
# \hline
# \end{array}
# \end{aligned}
# $$
#
# How did we come up with these priors? In this case, we rely on the domain expertise and previous research  (https://www.science.org/doi/10.1126/science.abb9789). In addition, the new parameter $\psi$ follows an exponential distribution, which restricts it to positive numbers. Below is the implementation of these priors:

# %%
def prior():
    """A random draw from the joint prior over the five parameters."""
    lambd = RNG.lognormal(mean=np.log(0.4), sigma=0.5)
    mu    = RNG.lognormal(mean=np.log(1 / 8), sigma=0.2)
    D     = RNG.lognormal(mean=np.log(8), sigma=0.2)
    I0    = RNG.gamma(shape=2, scale=20)
    psi   = RNG.exponential(5)
    return {"lambd": lambd, "mu": mu, "D": D, "I0": I0, "psi": psi}

nice_param_names = [r"$\lambda$", r"$\mu$", r"$D$", r"$I_0$", r"$\psi$"]

# %% [markdown]
# ### The observation model
#
# The simulator integrates the ODE to calculate the **expected** reported new cases per day and then adds Negative-Binomial reporting noise on top.
#
# The helper `convert_params` converts the (mean, dispersion) parameterisation of the Negative-Binomial into the `(n, p)` form NumPy expects.

# %%
def convert_params(mu, phi):
    """Helper function to convert mean/dispersion parameterization of a negative binomial to N and p,
    as expected by numpy's negative_binomial.

    See https://en.wikipedia.org/wiki/Negative_binomial_distribution#Alternative_formulations
    """

    r = phi
    var = mu + 1 / r * mu**2
    p = (var - mu) / var
    return r, 1 - p


def stationary_SIR(lambd, mu, D, I0, psi, N=83e6, T=14, eps=1e-5, rng=None):
    """Performs a forward simulation from the stationary SIR model given a random draw from the prior."""
    if rng is None:
        rng = RNG
    # Extract parameters and round I0 and D
    I0 = np.ceil(I0)
    D = int(round(D))

    # Initial conditions
    S, I, R = [N - I0], [I0], [0]

    # Reported new cases
    C = [I0]

    # Simulate T-1 timesteps
    for t in range(1, T + D):
        # Calculate new cases
        I_new = lambd * (I[-1] * S[-1] / N)

        # SIR equations
        S_t = S[-1] - I_new
        I_t = np.clip(I[-1] + I_new - mu * I[-1], 0.0, N)
        R_t = np.clip(R[-1] + mu * I[-1], 0.0, N)

        # Track
        S.append(S_t)
        I.append(I_t)
        R.append(R_t)
        C.append(I_new)

    C = np.clip(np.array(C[D:]), 0, N)
    reparam = convert_params(C + eps, psi)
    C_obs = rng.negative_binomial(reparam[0], reparam[1])
    return dict(cases=C_obs, raw_cases=C)

# %% [markdown]
# Combine prior and simulator, and sanity-check the output shapes.

# %%
simulator = bf.make_simulator([prior, stationary_SIR])

test_sims = simulator.sample(batch_size=3)
print("lambd:", test_sims["lambd"].shape, " cases:", test_sims["cases"].shape)  # (3,1) (3,14)
# Out:
# lambd: (3, 1)  cases: (3, 14)

# %% [markdown]
# ### Prior predictive check
#
# A principled Bayesian workflow always inspects the prior. Let's look at the joint prior of $\lambda$, $\mu$, $D$.

# %%
prior_samples = simulator.simulators[0].sample(1000)
grid = bf.diagnostics.plots.pairs_samples(prior_samples, variable_keys=["lambd", "mu", "D"], variable_names=nice_param_names[:3])

# %% [markdown]
# ## 2. Adapter
#
# The raw data are large integer counts and the parameters live on very different scales — not network-friendly. We:
# - mark `cases` as a **time series** (`as_time_series`), giving it shape `(batch, T, 1)`,
# - concatenate the five parameters into `inference_variables`,
# - rename `cases` to `summary_variables` (they go through the summary network),
# - `log1p`-transform the data.
# - constrain the parameters to be positive (the network will learn to output unconstrained values, which are then transformed to the constrained space).

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    # TODO(1a): mark 'cases' as a time series so it becomes shape (batch, T, 1)
    #   Hint: .as_time_series(<name>)
    .as_time_series("cases") # <-- add it here

    # TODO(1b): concatenate the 5 parameters into 'inference_variables'
    #   Hint: .concatenate(<list>, into="inference_variables")
    .concatenate(['lambd','mu', 'D', 'I0', 'psi'],into="inference_variables" )# <-- add it here

    .rename("cases", "summary_variables")
    # TODO(1c): log1p-transform summary_variables
    #   Hint: .log() has a p1 argument
    .log("summary_variables", p1=True) # <-- add it here
    # TODO(1d) .constrain the parameters to be positive
    .constrain("inference_variables", lower=0)# <-- add it here
)

adapted = adapter(simulator.sample(2))
print(adapted["summary_variables"].shape, adapted["inference_variables"].shape)
# Out:
# (2, 14, 1) (2, 5)

# %% [markdown]
# ## 3. Networks & workflow
#
# Because our data is a **sequence**, we use a small custom **GRU** summary network. Any Keras model can plug into BayesFlow by subclassing `SummaryNetwork`. The `@serializable` decorator lets us save/load the full approximator later. BayesFlow has a lot of summary network architectures built in, but here we illustrate how to build a custom one.
#
# For the inference network we again use a `CouplingFlow`.

# %%
@bf.utils.serialization.serializable("custom")
class GRU(bf.networks.SummaryNetwork):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.gru = keras.layers.GRU(64)
        self.summary_projection = keras.layers.Dense(8)

    def call(self, time_series, **kwargs):
        """Compress (batch, T, 1) time series into (batch, 8) summaries."""
        summary = self.gru(time_series, **kwargs)
        summary = self.summary_projection(summary)
        return summary


summary_net = GRU()
inference_net = bf.networks.CouplingFlow(depth=2, transform="spline")

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    inference_network=inference_net,
    summary_network=summary_net,
)

# %% [markdown]
# ## 4. Training (offline)
#
# The simulator is fast, but to illustrate a realistic *low simulation budget* we pre-generate a fixed dataset and train **offline**. ~1 minute on Colab CPU.

# %%
training_data = workflow.simulate(6000)
validation_data = workflow.simulate(300)

history = workflow.fit_offline(
    data=training_data, epochs=100, batch_size=64, validation_data=validation_data
)
f = bf.diagnostics.plots.loss(history)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 6.9210 - val_loss: 6.6393
# Epoch 2/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0331 - val_loss: 5.4717
# Epoch 3/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4966 - val_loss: 5.3172
# Epoch 4/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2356 - val_loss: 5.0069
# Epoch 5/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1229 - val_loss: 5.5983
# Epoch 6/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0995 - val_loss: 4.8813
# Epoch 7/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8256 - val_loss: 4.7138
# Epoch 8/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6624 - val_loss: 4.5848
# Epoch 9/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5397 - val_loss: 4.5316
# Epoch 10/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4790 - val_loss: 4.2949
# Epoch 11/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3253 - val_loss: 4.1517
# Epoch 12/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3215 - val_loss: 4.1365
# Epoch 13/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2485 - val_loss: 4.2297
# Epoch 14/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1849 - val_loss: 4.1869
# Epoch 15/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.0374 - val_loss: 4.0171
# Epoch 16/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0396 - val_loss: 3.9634
# Epoch 17/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.0297 - val_loss: 3.9561
# Epoch 18/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.9548 - val_loss: 3.8602
# Epoch 19/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8841 - val_loss: 3.8871
# Epoch 20/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.8455 - val_loss: 4.0736
# Epoch 21/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.8208 - val_loss: 3.7790
# Epoch 22/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7541 - val_loss: 3.7496
# Epoch 23/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7524 - val_loss: 3.9588
# Epoch 24/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7196 - val_loss: 3.6021
# Epoch 25/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7472 - val_loss: 3.7789
# Epoch 26/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6849 - val_loss: 3.9685
# Epoch 27/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.6723 - val_loss: 3.5569
# Epoch 28/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6119 - val_loss: 3.7101
# Epoch 29/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6287 - val_loss: 3.5379
# Epoch 30/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5981 - val_loss: 3.8229
# Epoch 31/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6133 - val_loss: 3.5185
# Epoch 32/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5409 - val_loss: 3.5093
# Epoch 33/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5856 - val_loss: 3.4587
# Epoch 34/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4928 - val_loss: 3.6605
# Epoch 35/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4796 - val_loss: 3.7072
# Epoch 36/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4488 - val_loss: 3.5364
# Epoch 37/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4606 - val_loss: 3.4675
# Epoch 38/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4411 - val_loss: 3.5248
# Epoch 39/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4002 - val_loss: 3.7044
# Epoch 40/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3505 - val_loss: 3.3900
# Epoch 41/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3880 - val_loss: 3.4460
# Epoch 42/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3514 - val_loss: 3.3802
# Epoch 43/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.2989 - val_loss: 3.4212
# Epoch 44/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.2852 - val_loss: 3.4972
# Epoch 45/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.2628 - val_loss: 3.2993
# Epoch 46/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.2396 - val_loss: 3.3051
# Epoch 47/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.2469 - val_loss: 3.3021
# Epoch 48/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2023 - val_loss: 3.3506
# Epoch 49/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1723 - val_loss: 3.3836
# Epoch 50/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1504 - val_loss: 3.2595
# Epoch 51/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0930 - val_loss: 3.1966
# Epoch 52/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0854 - val_loss: 3.1944
# Epoch 53/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0711 - val_loss: 3.2291
# Epoch 54/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0564 - val_loss: 3.2103
# Epoch 55/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0373 - val_loss: 3.1271
# Epoch 56/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0077 - val_loss: 3.1377
# Epoch 57/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9748 - val_loss: 3.0983
# Epoch 58/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9779 - val_loss: 3.2060
# Epoch 59/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9546 - val_loss: 3.0424
# Epoch 60/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9127 - val_loss: 3.0582
# Epoch 61/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9072 - val_loss: 3.0687
# Epoch 62/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9103 - val_loss: 3.1496
# Epoch 63/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8887 - val_loss: 3.0423
# Epoch 64/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8659 - val_loss: 3.2478
# Epoch 65/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9000 - val_loss: 3.1701
# Epoch 66/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8583 - val_loss: 2.9915
# Epoch 67/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8284 - val_loss: 2.9840
# Epoch 68/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8354 - val_loss: 3.0195
# Epoch 69/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.8329 - val_loss: 3.0931
# Epoch 70/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.8440 - val_loss: 3.0867
# Epoch 71/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.8085 - val_loss: 2.9729
# Epoch 72/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.7967 - val_loss: 2.9670
# Epoch 73/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.7971 - val_loss: 3.0723
# Epoch 74/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7884 - val_loss: 2.9747
# Epoch 75/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7886 - val_loss: 2.9718
# Epoch 76/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7724 - val_loss: 2.9502
# Epoch 77/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7591 - val_loss: 2.9445
# Epoch 78/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7549 - val_loss: 2.9620
# Epoch 79/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7477 - val_loss: 2.9616
# Epoch 80/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7531 - val_loss: 2.9837
# Epoch 81/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7345 - val_loss: 2.9224
# Epoch 82/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7269 - val_loss: 2.9173
# Epoch 83/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7227 - val_loss: 2.9230
# Epoch 84/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7200 - val_loss: 2.9270
# Epoch 85/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7187 - val_loss: 2.9286
# Epoch 86/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7049 - val_loss: 2.9236
# Epoch 87/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7119 - val_loss: 2.9352
# Epoch 88/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7068 - val_loss: 2.9460
# Epoch 89/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7023 - val_loss: 2.9155
# Epoch 90/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6956 - val_loss: 2.9223
# Epoch 91/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6989 - val_loss: 2.9130
# Epoch 92/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6833 - val_loss: 2.9194
# Epoch 93/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6914 - val_loss: 2.9149
# Epoch 94/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6818 - val_loss: 2.9168
# Epoch 95/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6832 - val_loss: 2.9183
# Epoch 96/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6893 - val_loss: 2.9111
# Epoch 97/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.6745 - val_loss: 2.9164
# Epoch 98/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.6888 - val_loss: 2.9108
# Epoch 99/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6880 - val_loss: 2.9122
# Epoch 100/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6942 - val_loss: 2.9119
# INFO:bayesflow:Training completed in 1.63 minutes.

# %% [markdown]
# ## 5. Diagnostics
#
# A converged loss is **not** proof of correct inference. We validate *in silico* (on fresh simulations where we know the truth) before ever touching real data.
#
# First, draw posterior samples for 300 fresh test datasets.

# %%
num_datasets, num_samples = 300, 1000
test_sims = workflow.simulate(num_datasets)
samples = workflow.sample(conditions=test_sims, num_samples=num_samples, batch_size=50)
# Out:
# Summarizing:   0%|          | 0/6 [00:00<?, ?batch/s]
# Sampling:   0%|          | 0/6 [00:00<?, ?batch/s]
# INFO:bayesflow:Sampling completed in 12.21 seconds.

# %% [markdown]
# ### 5a. Simulation-based calibration (SBC)
#
# If the posterior is well calibrated, the rank of each true value among the posterior draws is **uniform**. Rank **histograms** should look flat; the **ECDF-difference** should stay inside the band. (ECDF is usually easier to read for many parameters.)
#
# > SBC papers: rank histograms <https://arxiv.org/abs/1804.06788> · ECDF <https://arxiv.org/abs/2103.10522>
# >
# > BayesFlow guide: https://bayesflow.org/v2.0.12/user_guide/diagnostics.html

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %%
# TODO(2): produce an SBC ECDF-difference plot.
#   Hint: check the BayesFlow guide for the available calibration plot, one line of code is needed here
# f = bf.diagnostics.plots.calibration_ecdf(samples, test_sims, variable_names=nice_param_names)
f = bf.diagnostics.calibration_ecdf(samples, test_sims)  # <-- replace this

# %%
f = bf.diagnostics.plots.calibration_histogram(samples, test_sims, variable_names=nice_param_names)
# Out:
# WARNING:bayesflow:The ratio of simulations / posterior draws should be > 20 for reliable variance reduction, but your ratio is 0. Confidence intervals might be unreliable!

# %% [markdown]
# ### 5b. Recovery & the non-identifiability lesson
#
# Now compare posterior means to ground truth.

# %%
# TODO(3): make a recovery plot (you can look up the function again in the guide)
f = bf.diagnostics.plots.recovery(samples, test_sims)  # <-- replace this

# %% [markdown]
# > 🔎 **Interpret before you scroll.** Look at the recovery plots for $\mu$ and $D$. They probably look *flat* — the estimate barely moves with the truth. **Is training broken?**
# >
# > No. From only 14 days of case counts, $\mu$ (recovery rate) and $D$ (reporting delay) are **weakly identified**: many parameter combinations produce near-identical data. No inference method — BayesFlow, MCMC, anything — can recover what the data doesn't contain. A flat recovery plot combined with **good calibration** is the signature of non-identifiability, not a bug. This is exactly why we run diagnostics.

# %% [markdown]
# ### 5c. Automatic numerical diagnostics
#
# The workflow can compute the 'big three' error metrics — NRMSE, calibration error, posterior contraction — in one call. **Posterior contraction near 0** for a parameter is another fingerprint of non-identifiability (the posterior is as wide as the prior).

# %%
metrics = workflow.compute_default_diagnostics(test_data=test_sims, samples=samples, variable_names=nice_param_names)
metrics
# Out:
# WARNING:bayesflow:Using new default normalize='prior' for a more dynamic range. To reproduce previous behavior, set normalize='range'.
#                        $\lambda$     $\mu$       $D$     $I_0$    $\psi$
# NRMSE                   0.192946  0.993950  0.940580  0.801734  0.461841
# Log Gamma               3.671878  4.359373  4.233051  1.608258 -0.685207
# Calibration Error       0.004912  0.023421  0.006228  0.011404  0.021930
# Posterior Contraction   0.969160  0.088321  0.157100  0.343887  0.807360

# %%
# The full graphical diagnostic panel in one call
figures = workflow.plot_default_diagnostics(
    test_data=test_sims, samples=samples,
    loss_kwargs={"figsize": (15, 3)}, recovery_kwargs={"figsize": (15, 3)},
    calibration_ecdf_kwargs={"figsize": (15, 3)}, z_score_contraction_kwargs={"figsize": (15, 3)},
    variable_names=nice_param_names
)

# %% [markdown]
# ## 6. Confronting real data: a posterior predictive check 📈
#
# In-silico diagnostics tell us the network is well calibrated *for data that looks like our simulator*. The final test is **real data**.
#
# We download the actual reported COVID-19 cases in Germany for the first two weeks of March 2020, infer the posterior with our trained network, and run a **posterior predictive check (PPC)**: draw parameters from the posterior, re-simulate case trajectories, and overlay them on the observed series. If the model is adequate, the observations should fall within the predictive band.

# %%
import datetime, pandas as pd

def load_data():
    """Download daily reported COVID-19 cases in Germany, 1-14 March 2020 (needs internet)."""
    url = ("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/"
           "csse_covid_19_data/csse_covid_19_time_series/"
           "time_series_covid19_confirmed_global.csv")
    df = pd.read_csv(url)
    fmt = lambda d: f"{d.month}/{d.day}/{str(d.year)[2:4]}"
    b, e = datetime.date(2020, 3, 1), datetime.date(2020, 3, 15)
    cum = np.array(df.loc[df["Country/Region"] == "Germany", fmt(b):fmt(e)])[0]
    return np.diff(cum)  # daily new cases = differences of the cumulative counts

real_cases = load_data()

plt.figure(figsize=(9, 3))
plt.plot(real_cases, "-o", color="black")
plt.xlabel("day (from 1 March 2020)"); plt.ylabel("reported new cases")
plt.title("Real German COVID-19 cases, early March 2020");

# %% [markdown]
# ### Posterior predictive check
#
# The helper below draws re-simulations from the posterior (one trajectory per posterior sample) and overlays their median and credible bands on the observed data.

# %%
def plot_ppc(param_df, obs_cases, sim_fn, logscale=True, color="#132a70", title="", seed=2026):
    """Overlay posterior re-simulations (from sim_fn) on the observed data."""
    rng = np.random.default_rng(seed)  # seed the reporting noise so the check is reproducible
    T = len(obs_cases)
    sims = []
    for row in param_df.values:
        try:
            sims.append(sim_fn(*row, rng=rng)["cases"])
        except ValueError:
            continue  # drop the rare out-of-support posterior draw (e.g. psi == 0)
    sims = np.array(sims)
    q50 = np.quantile(sims, [0.25, 0.75], axis=0)
    q90 = np.quantile(sims, [0.05, 0.95], axis=0)
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.plot(np.median(sims, axis=0), color=color, label="median re-simulation")
    ax.fill_between(range(T), q50[0], q50[1], color=color, alpha=0.4, label="50% CI")
    ax.fill_between(range(T), q90[0], q90[1], color=color, alpha=0.2, label="90% CI")
    ax.plot(obs_cases, "o--", color="black", alpha=0.8, label="observed")
    if logscale: ax.set_yscale("log")
    ax.set_xlabel("day"); ax.set_ylabel("cases"); ax.set_title(title); ax.legend()
    return fig

# %%
post = workflow.sample(conditions={"cases": real_cases[None, :]}, num_samples=1000)
post_df = workflow.samples_to_data_frame(post)

f = plot_ppc(post_df, real_cases, sim_fn=stationary_SIR,
             title="Posterior predictive check — real German COVID-19 data")
# Out:
# Summarizing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Sampling:   0%|          | 0/1 [00:00<?, ?batch/s]
# INFO:bayesflow:Sampling completed in 8.92 seconds.

# %% [markdown]
# > 🔎 **What to look for.** If the observed points mostly fall inside the predictive band, the SIR model is an adequate description of the early outbreak. Systematic structure in the residuals — for instance the observed series repeatedly leaving the band on the same weekday — would flag **model misspecification**: a real effect (such as reduced weekend reporting) that the simulator does not capture. The posterior can still look confident in that case, which is exactly why the PPC is the essential last check before trusting the results.

# %% [markdown]
# ## 🎉 Summary
#
# You trained an amortized estimator for a mechanistic time-series model, learned to **read** SBC / recovery / contraction diagnostics, recognised **non-identifiability**, and confronted the network with **real COVID-19 data** through a **posterior predictive check**.

# %% [markdown]
# ---
#
# You can find a solution to this exercise [here](https://colab.research.google.com/github/arrjon/BayesFlowTutorial/blob/main/02_SIR_Diagnostics_Solution.ipynb). If you liked this notebook, leave a star on the [BayesFlow Repository](https://github.com/bayesflow-org/bayesflow).
